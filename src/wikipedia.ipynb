# %%
import requests
from pprint import pprint
import pickle
from tqdm import tqdm
import re

# %%
def get_info(name = "Kanye West"):
    info = {}

    url = 'https://query.wikidata.org/sparql'
    query = """
        SELECT DISTINCT ?item ?birthLocation ?birthLocationLabel ?Twitter_username ?Instagram_username ?occupation ?occupationLabel ?date_of_birth ?sex_or_gender ?sex_or_genderLabel ?country_of_citizenship ?country_of_citizenshipLabel ?image 
        WHERE {
            """ + f'?item rdfs:label "{name}"@en ;' + """ 
            SERVICE wikibase:label { bd:serviceParam wikibase:language "en". }

            OPTIONAL { ?item wdt:P19   ?birthLocation. }
            OPTIONAL { ?item wdt:P2002 ?Twitter_username. }
            OPTIONAL { ?item wdt:P2003 ?Instagram_username. }
            OPTIONAL { ?item wdt:P106  ?occupation. }
            OPTIONAL { ?item wdt:P569  ?date_of_birth. }
            OPTIONAL { ?item wdt:P21   ?sex_or_gender. }
            OPTIONAL { ?item wdt:P27   ?country_of_citizenship. }
            OPTIONAL { ?item wdt:P18   ?image. }
        }
    """
    r = requests.get(url, params = {'format': 'json', 'query': query})
    data = r.json()  

    if len(data['results']['bindings']) == 0:
        raise Exception(f"No results for {name}")

    b = data['results']['bindings']
    person = set([x['item']['value'] for x in b])

    if len(person) > 1:
        raise Exception(f"Multiple person results for {name}")

    optionals = ['Twitter_username', 'Instagram_username', 'occupation', 'date_of_birth', 'sex_or_gender', 'country_of_citizenship', 'image', 'birthLocation', 'birthLocationLabel']
    info = {}
    for opt in optionals:
        all_values = list(set([res.get(opt)['value'] for res in b if opt in res]))
        info[opt] = all_values

    info['personUri'] = list(person)[0]
    info['person'] = name

    return info

# %%
CACHE = "./jre-episodes.pickle"
with open(CACHE, "rb") as f:
    episodes = pickle.load(f)

# %%
names = []
for ep in episodes:
    # name = re.findall(r"- ([A-Z].*)", ep.title)
    name = re.findall(r"#\d\d?\d?\d? ?-?-? .*?([A-Z].*)", ep.title)
    skip_best = "Best of " in ep.title
    skip_toon = "JRE Toon" in ep.title
    skip_fight_companion = "Fight Companion" in ep.title
    skip_mma = "JRE MMA Show" in ep.title
    skip_from_jre = "from Joe Rogan" in ep.title or "from JRE" in ep.title
    skip_questions = "Questions Everything" in ep.title
    if skip_best or skip_toon or skip_fight_companion or skip_from_jre or skip_mma or skip_questions:
        # print(ep.title)
        # "from Joe Rogan Experience" not in ep.title
        continue
    elif len(name) == 0:
        # NOT CAPTURED
        # print(ep.title)
        continue
    else:
        name = name[0]
        if not ep.number:
            continue
        
        # if "Part 2" in name:
        #     print(name)
        # else:
        #     # print(ep.title)
        names.append((ep, name))

nums = [e.number for e, n in names]
for i in range(1539):
    if i+1 not in nums:
        print("missing", i+1)
# Out:
# missing 4
# missing 8
# missing 10
# missing 22
# missing 23
# missing 32
# missing 36
# missing 41
# missing 42
# missing 43
# missing 48
# missing 49
# missing 50
# missing 51
# missing 52
# missing 56
# missing 57
# missing 60
# missing 61
# missing 62
# missing 63
# missing 64
# missing 65
# missing 66
# missing 67
# missing 68
# missing 69
# missing 70
# missing 78
# missing 81
# missing 85
# missing 86
# missing 92
# missing 97
# missing 99
# missing 104
# missing 108
# missing 120
# missing 128
# missing 149
# missing 160
# missing 164
# missing 168
# missing 169
# missing 174
# missing 182
# missing 183
# missing 191
# missing 195
# missing 198
# missing 210
# missing 213
# missing 223
# missing 225
# missing 229
# missing 230
# missing 233
# missing 238
# missing 242
# missing 243
# missing 247
# missing 248
# missing 257
# missing 265
# missing 287
# missing 294
# missing 296
# missing 302
# missing 303
# missing 306
# missing 307
# missing 309
# missing 311
# missing 313
# missing 315
# missing 318
# missing 320
# missing 326
# missing 327
# missing 341
# missing 342
# missing 343
# missing 353
# missing 364
# missing 370
# missing 378
# missing 388
# missing 389
# missing 391
# missing 394
# missing 395
# missing 397
# missing 401
# missing 402
# missing 403
# missing 404
# missing 409
# missing 420
# missing 422
# missing 423
# missing 425
# missing 426
# missing 427
# missing 428
# missing 429
# missing 430
# missing 432
# missing 433
# missing 435
# missing 439
# missing 441
# missing 444
# missing 447
# missing 453
# missing 454
# missing 455
# missing 456
# missing 458
# missing 461
# missing 462
# missing 465
# missing 466
# missing 471
# missing 480
# missing 481
# missing 493
# missing 494
# missing 495
# missing 706
# missing 821

# %%
guest_data = []

# %%
import time
errors = []

# Super hacky but populate guest data 
# with some basic info like ig and twitter username, and the eps they were in

for ep, name_ in tqdm(names):
    # print(ep.description)
    names2 = [name_]
    if "," in name_:
        names2 = name_.split(",")
    elif "&" in name_:
        names2 = name_.split("&")

    for name in names2:
        hits = [g for g in guest_data if g['person'].lower() == name.lower()]
        if len(hits) > 0:
            if hits[0].get('episodes') is None:
                hits[0]['episodes'] = []
            hits[0]['episodes'] = hits[0].get('episodes', []).append(ep.video_id)
            continue
        try:
            time.sleep(.75)
            info = get_info(str(name).strip())
            info['episodes'] = [ep.video_id]
            guest_data.append(info)
        except Exception as e:
            print(name, e)
            errors.append((name, e))
# Out:
# |███████▎  | 1053/1438 [11:02<05:18,  1.21it/s]David Seaman Multiple person results for David Seaman
# Brendan Schaub  Expecting value: line 1 column 1 (char 0)
#  74%|███████▎  | 1057/1438 [11:05<05:52,  1.08it/s]Mark Kendall Multiple person results for Mark Kendall
# Rob MacCachren  Expecting value: line 1 column 1 (char 0)
#  74%|███████▍  | 1061/1438 [11:09<06:33,  1.04s/it] Josh Wickerham Expecting value: line 1 column 1 (char 0)
#  74%|███████▍  | 1062/1438 [11:10<06:34,  1.05s/it]Honey Honey Multiple person results for Honey Honey
#  74%|███████▍  | 1065/1438 [11:11<05:17,  1.18it/s]Jim Jefferies Multiple person results for Jim Jefferies
#  74%|███████▍  | 1066/1438 [11:12<05:34,  1.11it/s]Shane Smith Multiple person results for Shane Smith
#  74%|███████▍  | 1068/1438 [11:13<04:41,  1.31it/s]Dr. Carl Hart Expecting value: line 1 column 1 (char 0)
#  74%|███████▍  | 1069/1438 [11:14<05:17,  1.16it/s] Christopher Ryan Multiple person results for Christopher Ryan
#  74%|███████▍  | 1070/1438 [11:15<05:36,  1.10it/s]Peter Giuliano No results for Peter Giuliano
# Robert Greene Multiple person results for Robert Greene
#  74%|███████▍  | 1071/1438 [11:17<07:28,  1.22s/it] Aubrey Marcus No results for Aubrey Marcus
#  75%|███████▍  | 1074/1438 [11:18<05:43,  1.06it/s]Dr. Rhonda Patrick Expecting value: line 1 column 1 (char 0)
#  75%|███████▍  | 1077/1438 [11:21<05:52,  1.02it/s]Aubrey Marcus No results for Aubrey Marcus
#  75%|███████▍  | 1078/1438 [11:22<05:43,  1.05it/s]Cameron Hanes Expecting value: line 1 column 1 (char 0)
#  75%|███████▌  | 1079/1438 [11:23<05:43,  1.05it/s]Justin Martindale No results for Justin Martindale
#  75%|███████▌  | 1082/1438 [11:24<04:30,  1.32it/s]Peter Schiff Expecting value: line 1 column 1 (char 0)
#  76%|███████▌  | 1086/1438 [11:25<03:32,  1.65it/s]Dr. Mark Gordon No results for Dr. Mark Gordon
#  76%|███████▌  | 1090/1438 [11:26<02:50,  2.04it/s]Matt Fulchiron (Part 1) Expecting value: line 1 column 1 (char 0)
#  76%|███████▌  | 1092/1438 [11:27<02:45,  2.09it/s]Christopher Ryan Multiple person results for Christopher Ryan
#  76%|███████▌  | 1093/1438 [11:28<03:28,  1.66it/s]Lorenzo Hagerty (Part 2) Expecting value: line 1 column 1 (char 0)
#  76%|███████▋  | 1097/1438 [11:30<03:28,  1.64it/s]Justin Foster No results for Justin Foster
#  76%|███████▋  | 1098/1438 [11:31<03:57,  1.43it/s]Cmdr. Chris Hadfield Expecting value: line 1 column 1 (char 0)
#  77%|███████▋  | 1102/1438 [11:33<03:35,  1.56it/s]Sam Harris Expecting value: line 1 column 1 (char 0)
#  77%|███████▋  | 1105/1438 [11:34<03:01,  1.84it/s]Steven Pressfield Expecting value: line 1 column 1 (char 0)
#  77%|███████▋  | 1106/1438 [11:35<05:04,  1.09it/s] Aubrey Marcus No results for Aubrey Marcus
# Joey "CoCo" Diaz Expecting value: line 1 column 1 (char 0)
#  77%|███████▋  | 1113/1438 [11:38<04:49,  1.12it/s]Mac Lethal Expecting value: line 1 column 1 (char 0)
#  77%|███████▋  | 1114/1438 [11:39<05:03,  1.07it/s]Everlast Multiple person results for Everlast
#  78%|███████▊  | 1115/1438 [11:40<05:11,  1.04it/s]Joey "CoCo" Diaz Expecting value: line 1 column 1 (char 0)
#  78%|███████▊  | 1116/1438 [11:42<06:37,  1.24s/it] TJ Dillashaw Expecting value: line 1 column 1 (char 0)
#  78%|███████▊  | 1117/1438 [11:43<06:05,  1.14s/it]Ian McCall Multiple person results for Ian McCall
#  78%|███████▊  | 1118/1438 [11:44<05:41,  1.07s/it]Jim Norton Expecting value: line 1 column 1 (char 0)
#  78%|███████▊  | 1120/1438 [11:45<04:45,  1.11it/s]Abby Martin Multiple person results for Abby Martin
# Matt Farah No results for Matt Farah
#  78%|███████▊  | 1122/1438 [11:47<04:56,  1.07it/s] Tod Mesirow No results for Tod Mesirow
#  78%|███████▊  | 1125/1438 [11:48<03:56,  1.32it/s]Shane Smith Multiple person results for Shane Smith
#  78%|███████▊  | 1127/1438 [11:49<03:26,  1.51it/s]Joey "CoCo" Diaz Expecting value: line 1 column 1 (char 0)
#  79%|███████▊  | 1130/1438 [11:51<03:20,  1.54it/s] Ari Shaffir Expecting value: line 1 column 1 (char 0)
#  79%|███████▊  | 1131/1438 [11:52<03:58,  1.29it/s]David Seaman Multiple person results for David Seaman
#  79%|███████▊  | 1132/1438 [11:53<04:08,  1.23it/s]Aubrey Marcus No results for Aubrey Marcus
#  79%|███████▉  | 1134/1438 [11:55<04:23,  1.16it/s] Glen Cordoza No results for Glen Cordoza
#  79%|███████▉  | 1135/1438 [11:56<04:25,  1.14it/s]Everlast Expecting value: line 1 column 1 (char 0)
#  79%|███████▉  | 1136/1438 [11:57<04:31,  1.11it/s]Joey "CoCo" Diaz Expecting value: line 1 column 1 (char 0)
#  79%|███████▉  | 1137/1438 [11:57<04:30,  1.11it/s]Kevin Pereira Expecting value: line 1 column 1 (char 0)
#  79%|███████▉  | 1140/1438 [11:58<03:36,  1.38it/s]Rich Roll No results for Rich Roll
#  79%|███████▉  | 1141/1438 [11:59<03:49,  1.30it/s]Freeway" Rick Ross Expecting value: line 1 column 1 (char 0)
#  79%|███████▉  | 1143/1438 [12:00<03:22,  1.46it/s]Tom Segura (Part 2) No results for Tom Segura (Part 2)
#  80%|███████▉  | 1144/1438 [12:01<03:40,  1.34it/s]Tom Segura (Part 1) Expecting value: line 1 column 1 (char 0)
#  80%|███████▉  | 1149/1438 [12:04<04:13,  1.14it/s]David Seaman Multiple person results for David Seaman
#  80%|████████  | 1152/1438 [12:05<03:21,  1.42it/s]Everlast Expecting value: line 1 column 1 (char 0)
#  80%|████████  | 1155/1438 [12:06<02:46,  1.70it/s]Joey "CoCo" Diaz Expecting value: line 1 column 1 (char 0)
#  80%|████████  | 1157/1438 [12:07<02:33,  1.83it/s]Maynard James Keenan (Part 2) Expecting value: line 1 column 1 (char 0)
#  81%|████████  | 1158/1438 [12:08<03:13,  1.45it/s]Maynard James Keenan (Part 1) No results for Maynard James Keenan (Part 1)
#  81%|████████  | 1159/1438 [12:09<03:34,  1.30it/s]Robb Wolf No results for Robb Wolf
#  81%|████████  | 1161/1438 [12:10<03:06,  1.49it/s]James "Bobo" Fay Expecting value: line 1 column 1 (char 0)
#  81%|████████  | 1162/1438 [12:11<03:28,  1.32it/s]Aubrey Marcus No results for Aubrey Marcus
#  81%|████████  | 1164/1438 [12:12<03:01,  1.51it/s]Josh Barnett (Part 2) Expecting value: line 1 column 1 (char 0)
#  81%|████████  | 1165/1438 [12:13<03:25,  1.33it/s]Josh Barnett (Part 1) No results for Josh Barnett (Part 1)
#  81%|████████  | 1166/1438 [12:14<03:37,  1.25it/s]Adam Kokesh Expecting value: line 1 column 1 (char 0)
#  81%|████████  | 1168/1438 [12:15<03:15,  1.38it/s]Adam Scorgie No results for Adam Scorgie
#  81%|████████▏ | 1169/1438 [12:16<03:38,  1.23it/s]Giorgio Tsoukalos No results for Giorgio Tsoukalos
#  81%|████████▏ | 1171/1438 [12:18<03:53,  1.15it/s] Tait Fletcher Expecting value: line 1 column 1 (char 0)
#  82%|████████▏ | 1173/1438 [12:19<03:21,  1.32it/s]Alex Grey Multiple person results for Alex Grey
#  82%|████████▏ | 1181/1438 [12:19<02:25,  1.77it/s]Brian Redban Expecting value: line 1 column 1 (char 0)
#  82%|████████▏ | 1182/1438 [12:20<02:55,  1.46it/s]John Anthony West Multiple person results for John Anthony West
#  82%|████████▏ | 1183/1438 [12:21<03:11,  1.33it/s] Joey Diaz Expecting value: line 1 column 1 (char 0)
#  82%|████████▏ | 1184/1438 [12:22<03:29,  1.21it/s]Shane Smith Multiple person results for Shane Smith
#  83%|████████▎ | 1188/1438 [12:23<02:44,  1.52it/s]Michael Ruppert Multiple person results for Michael Ruppert
#  83%|████████▎ | 1193/1438 [12:24<02:06,  1.93it/s]Ari Shaffir (Part 1) No results for Ari Shaffir (Part 1)
#  83%|████████▎ | 1194/1438 [12:25<02:34,  1.58it/s]Ari Shaffir (Part 2) Expecting value: line 1 column 1 (char 0)
#  83%|████████▎ | 1200/1438 [12:27<01:51,  2.14it/s] Amy Schumer Expecting value: line 1 column 1 (char 0)
#  84%|████████▎ | 1202/1438 [12:28<01:51,  2.12it/s]Georges St. Pierre No results for Georges St. Pierre
#  Bryan Callen Expecting value: line 1 column 1 (char 0)
#  84%|████████▍ | 1205/1438 [12:30<02:00,  1.94it/s] Cam Edwards No results for Cam Edwards
#  84%|████████▍ | 1209/1438 [12:31<01:37,  2.34it/s]Jim Jefferies Expecting value: line 1 column 1 (char 0)
#  84%|████████▍ | 1211/1438 [12:32<01:40,  2.25it/s]EverLast Multiple person results for EverLast
#  84%|████████▍ | 1214/1438 [12:33<01:29,  2.50it/s]Matt Paxton Expecting value: line 1 column 1 (char 0)
#  85%|████████▍ | 1216/1438 [12:34<01:40,  2.20it/s]Sam Harris Multiple person results for Sam Harris
# DEADMAU5 No results for DEADMAU5
#  Russell Peters Expecting value: line 1 column 1 (char 0)
#  85%|████████▌ | 1225/1438 [12:37<01:58,  1.79it/s]Douglas Rushkoff Expecting value: line 1 column 1 (char 0)
#  85%|████████▌ | 1227/1438 [12:39<02:20,  1.50it/s] Christopher Ryan Expecting value: line 1 column 1 (char 0)
#  85%|████████▌ | 1229/1438 [12:41<02:35,  1.34it/s] Denny Prokopos Expecting value: line 1 column 1 (char 0)
#  86%|████████▌ | 1232/1438 [12:42<02:07,  1.62it/s]Hamilton Morris Multiple person results for Hamilton Morris
#  86%|████████▌ | 1234/1438 [12:43<01:56,  1.76it/s]JD Kelley Expecting value: line 1 column 1 (char 0)
#  86%|████████▌ | 1235/1438 [12:44<02:18,  1.46it/s]Jacob Ward Multiple person results for Jacob Ward
#  86%|████████▌ | 1237/1438 [12:45<02:11,  1.53it/s]Peter Joseph Multiple person results for Peter Joseph
#  86%|████████▌ | 1239/1438 [12:46<01:57,  1.70it/s]EverLast (Part 1) Expecting value: line 1 column 1 (char 0)
#  86%|████████▌ | 1240/1438 [12:47<02:13,  1.48it/s]Shane Smith Multiple person results for Shane Smith
#  87%|████████▋ | 1244/1438 [12:48<01:44,  1.85it/s]Dr. Amit Goswami Expecting value: line 1 column 1 (char 0)
#  87%|████████▋ | 1248/1438 [12:49<01:26,  2.19it/s]Michael Ruppert Multiple person results for Michael Ruppert
#  87%|████████▋ | 1249/1438 [12:50<01:51,  1.69it/s]Aubrey Marcus No results for Aubrey Marcus
#  87%|████████▋ | 1250/1438 [12:51<02:08,  1.47it/s]Dr. Steven Greer Expecting value: line 1 column 1 (char 0)
#  87%|████████▋ | 1251/1438 [12:52<02:27,  1.26it/s]Eddie Huang Multiple person results for Eddie Huang
#  87%|████████▋ | 1254/1438 [12:53<01:59,  1.54it/s]James "The Colossus" Thompson Expecting value: line 1 column 1 (char 0)
#  87%|████████▋ | 1255/1438 [12:53<02:12,  1.38it/s]Sam Sheridan Expecting value: line 1 column 1 (char 0)
#  88%|████████▊ | 1259/1438 [12:56<02:17,  1.30it/s]Nick Thune Expecting value: line 1 column 1 (char 0)
#  88%|████████▊ | 1262/1438 [12:58<02:09,  1.36it/s]Bruce Lipton PHD (Part Two) Expecting value: line 1 column 1 (char 0)
#  88%|████████▊ | 1263/1438 [12:59<02:20,  1.25it/s]Bruce Lipton PHD (PART ONE) No results for Bruce Lipton PHD (PART ONE)
#  88%|████████▊ | 1269/1438 [13:00<01:42,  1.65it/s]Brian Redban Expecting value: line 1 column 1 (char 0)
# David Seaman Multiple person results for David Seaman
#  Abby Martin Multiple person results for Abby Martin
#  88%|████████▊ | 1271/1438 [13:03<02:23,  1.16it/s] Dell Cameron Expecting value: line 1 column 1 (char 0)
#  88%|████████▊ | 1272/1438 [13:04<02:46,  1.00s/it]London Real No results for London Real
#  89%|████████▊ | 1273/1438 [13:05<02:57,  1.07s/it]Alex Grey Multiple person results for Alex Grey
#  89%|████████▊ | 1274/1438 [13:08<04:01,  1.47s/it] Ian Edwards Multiple person results for Ian Edwards
#  89%|████████▉ | 1277/1438 [13:09<03:02,  1.14s/it]Philip Coppens Multiple person results for Philip Coppens
#  89%|████████▉ | 1278/1438 [13:10<03:05,  1.16s/it]Freeway" Rick Ross Expecting value: line 1 column 1 (char 0)
#  89%|████████▉ | 1280/1438 [13:11<02:29,  1.06it/s]Melissa Etheridge Expecting value: line 1 column 1 (char 0)
#  89%|████████▉ | 1283/1438 [13:12<02:02,  1.26it/s]Bryan Callen (Part One) No results for Bryan Callen (Part One)
#  89%|████████▉ | 1284/1438 [13:13<02:15,  1.14it/s]Bryan Callen (Part Two) No results for Bryan Callen (Part Two)
#  89%|████████▉ | 1285/1438 [13:14<02:21,  1.08it/s]Mayhem Miller Multiple person results for Mayhem Miller
#  89%|████████▉ | 1286/1438 [13:16<02:26,  1.04it/s]Kevin Pereira Multiple person results for Kevin Pereira
#  90%|█████████ | 1295/1438 [13:20<01:56,  1.22it/s]Brendon Walsh (Part 3) No results for Brendon Walsh (Part 3)
#  90%|█████████ | 1296/1438 [13:21<02:10,  1.09it/s]Brendon Walsh (Part 2) No results for Brendon Walsh (Part 2)
#  90%|█████████ | 1297/1438 [13:22<02:10,  1.08it/s]Daniel Pinchbeck (Part 3) No results for Daniel Pinchbeck (Part 3)
#  90%|█████████ | 1299/1438 [13:23<01:48,  1.28it/s]Kevin Smith (Part 3) Expecting value: line 1 column 1 (char 0)
#  90%|█████████ | 1300/1438 [13:23<01:54,  1.21it/s]Aubrey Marcus (Part 2) No results for Aubrey Marcus (Part 2)
#  91%|█████████ | 1302/1438 [13:24<01:37,  1.40it/s]Brendon Walsh (Part 1) Expecting value: line 1 column 1 (char 0)
#  91%|█████████ | 1304/1438 [13:25<01:26,  1.55it/s]Aubrey Marcus (Part 1) No results for Aubrey Marcus (Part 1)
#  91%|█████████ | 1305/1438 [13:26<01:35,  1.39it/s]Kevin Smith (Part 2) Expecting value: line 1 column 1 (char 0)
#  91%|█████████ | 1307/1438 [13:27<01:26,  1.52it/s]Freddy Lockhart (Part 2) No results for Freddy Lockhart (Part 2)
#  91%|█████████ | 1310/1438 [13:29<01:24,  1.52it/s]Daniel Pinchbeck (Part 2) Expecting value: line 1 column 1 (char 0)
#  91%|█████████ | 1311/1438 [13:30<01:35,  1.32it/s]Kevin Smith (Part 1) No results for Kevin Smith (Part 1)
#  91%|█████████ | 1312/1438 [13:31<01:40,  1.26it/s]Tim Ferriss Expecting value: line 1 column 1 (char 0)
#  91%|█████████▏| 1313/1438 [13:32<01:45,  1.19it/s]Freddy Lockhart (Part 1) No results for Freddy Lockhart (Part 1)
# Charlie Murphy  Expecting value: line 1 column 1 (char 0)
#  91%|█████████▏| 1314/1438 [13:34<02:24,  1.16s/it] Freeze Love No results for Freeze Love
#  91%|█████████▏| 1315/1438 [13:35<02:15,  1.10s/it]Daniel Pinchbeck (Part 1) No results for Daniel Pinchbeck (Part 1)
# Giorgio A. Tsoukalos Expecting value: line 1 column 1 (char 0)
#  92%|█████████▏| 1317/1438 [13:38<02:23,  1.18s/it] Yoshi Obayashi Expecting value: line 1 column 1 (char 0)
#  92%|█████████▏| 1318/1438 [13:39<02:15,  1.13s/it]Michael Schiavello (Part 2) No results for Michael Schiavello (Part 2)
#  92%|█████████▏| 1319/1438 [13:39<02:05,  1.06s/it]Michael Schiavello (Part 1) Expecting value: line 1 column 1 (char 0)
#  92%|█████████▏| 1320/1438 [13:40<02:01,  1.03s/it]Jan Irvin No results for Jan Irvin
# Russell Peters  Expecting value: line 1 column 1 (char 0)
#  92%|█████████▏| 1327/1438 [13:43<01:35,  1.16it/s] Chuck Lidell No results for Chuck Lidell
# Cliff Bleszinski  Expecting value: line 1 column 1 (char 0)
#  93%|█████████▎| 1331/1438 [13:45<01:19,  1.35it/s] Jon Christofaris No results for Jon Christofaris
#  93%|█████████▎| 1336/1438 [13:46<00:58,  1.75it/s]Steve Rannazzisi Expecting value: line 1 column 1 (char 0)
#  93%|█████████▎| 1337/1438 [13:47<01:09,  1.46it/s]Adam Carolla (Part 1) No results for Adam Carolla (Part 1)
#  93%|█████████▎| 1338/1438 [13:48<01:14,  1.34it/s]Bryan Callen (Part 2) Expecting value: line 1 column 1 (char 0)
#  93%|█████████▎| 1339/1438 [13:49<01:22,  1.20it/s]Bryan Callen (Part 1) No results for Bryan Callen (Part 1)
#  93%|█████████▎| 1342/1438 [13:50<01:05,  1.47it/s]Adam Carolla (Part 2) No results for Adam Carolla (Part 2)
#  93%|█████████▎| 1343/1438 [13:51<01:10,  1.35it/s]Brian Redban Expecting value: line 1 column 1 (char 0)
# Daryl Wright  No results for Daryl Wright
#  93%|█████████▎| 1344/1438 [13:53<01:40,  1.07s/it] Brian Whitaker Expecting value: line 1 column 1 (char 0)
#  94%|█████████▎| 1345/1438 [13:53<01:37,  1.04s/it]Kevin Pereira Multiple person results for Kevin Pereira
#  94%|█████████▎| 1347/1438 [13:54<01:18,  1.16it/s]Joey Diaz (Part 4) Expecting value: line 1 column 1 (char 0)
#  94%|█████████▎| 1348/1438 [13:55<01:19,  1.13it/s]Joey Diaz (Part 3) No results for Joey Diaz (Part 3)
#  94%|█████████▍| 1349/1438 [13:56<01:19,  1.12it/s]Joey Diaz (Part 2) Expecting value: line 1 column 1 (char 0)
#  94%|█████████▍| 1350/1438 [13:57<01:19,  1.10it/s]Eddie Bravo (Part 2) No results for Eddie Bravo (Part 2)
#  94%|█████████▍| 1351/1438 [13:58<01:19,  1.10it/s]Joey Diaz (Part 1) Expecting value: line 1 column 1 (char 0)
#  94%|█████████▍| 1353/1438 [13:59<01:06,  1.28it/s]Eddie Bravo (Part 1) No results for Eddie Bravo (Part 1)
#  94%|█████████▍| 1357/1438 [14:00<00:49,  1.63it/s]Dana Dearmond Expecting value: line 1 column 1 (char 0)
#  95%|█████████▍| 1360/1438 [14:01<00:41,  1.87it/s]Dave Foley Multiple person results for Dave Foley
#  95%|█████████▍| 1362/1438 [14:03<00:48,  1.55it/s] Ari Shaffir Expecting value: line 1 column 1 (char 0)
#  95%|█████████▍| 1364/1438 [14:04<00:46,  1.60it/s]Bobby Lee Multiple person results for Bobby Lee
#  95%|█████████▍| 1366/1438 [14:05<00:41,  1.72it/s]Allison Sciulla No results for Allison Sciulla
#  95%|█████████▌| 1372/1438 [14:06<00:29,  2.22it/s]Mayhem Miller Expecting value: line 1 column 1 (char 0)
# Dr. Peter Duesberg  No results for Dr. Peter Duesberg
#  96%|█████████▌| 1379/1438 [14:09<00:25,  2.33it/s]Chris Aubrey Marcus (Part 1) No results for Chris Aubrey Marcus (Part 1)
#  96%|█████████▌| 1380/1438 [14:10<00:33,  1.76it/s]Chris Aubrey Marcus (Part 2) Expecting value: line 1 column 1 (char 0)
#  96%|█████████▌| 1381/1438 [14:11<00:40,  1.40it/s]Tom Green Multiple person results for Tom Green
#  96%|█████████▌| 1382/1438 [14:12<00:45,  1.24it/s]Todd McCormick (Part 2) No results for Todd McCormick (Part 2)
#  96%|█████████▋| 1385/1438 [14:13<00:35,  1.49it/s]Tim Ferriss No results for Tim Ferriss
#  96%|█████████▋| 1386/1438 [14:14<00:39,  1.32it/s]Tyler Knight Multiple person results for Tyler Knight
#  96%|█████████▋| 1387/1438 [14:15<00:40,  1.26it/s] Eddie Bravo (Part 1) Expecting value: line 1 column 1 (char 0)
#  97%|█████████▋| 1388/1438 [14:16<00:42,  1.18it/s] Eddie Bravo (Part 2) No results for Eddie Bravo (Part 2)
# Joey Diaz  Expecting value: line 1 column 1 (char 0)
#  97%|█████████▋| 1393/1438 [14:18<00:30,  1.48it/s]Dane Cook Expecting value: line 1 column 1 (char 0)
#  97%|█████████▋| 1394/1438 [14:19<00:33,  1.31it/s]Mayhem Miller Multiple person results for Mayhem Miller
#  97%|█████████▋| 1395/1438 [14:20<00:34,  1.25it/s]Brian Redban Expecting value: line 1 column 1 (char 0)
#  97%|█████████▋| 1401/1438 [14:21<00:22,  1.63it/s]Brian Redban No results for Brian Redban
#  98%|█████████▊| 1403/1438 [14:22<00:20,  1.74it/s]Brian Redban No results for Brian Redban
#  98%|█████████▊| 1404/1438 [14:23<00:22,  1.49it/s]Brian Redban Expecting value: line 1 column 1 (char 0)
#  98%|█████████▊| 1406/1438 [14:25<00:25,  1.26it/s]Brian Redban Expecting value: line 1 column 1 (char 0)
#  98%|█████████▊| 1407/1438 [14:26<00:25,  1.22it/s]Brian Redban No results for Brian Redban
#  98%|█████████▊| 1408/1438 [14:27<00:25,  1.19it/s]Brian Redban Expecting value: line 1 column 1 (char 0)
#  98%|█████████▊| 1412/1438 [14:28<00:17,  1.52it/s]Ian Edwards Multiple person results for Ian Edwards
#  98%|█████████▊| 1413/1438 [14:29<00:18,  1.37it/s]Brian Redban Expecting value: line 1 column 1 (char 0)
#  98%|█████████▊| 1414/1438 [14:30<00:19,  1.25it/s]Brian Redban (Part 2) No results for Brian Redban (Part 2)
#  98%|█████████▊| 1415/1438 [14:30<00:19,  1.21it/s]Brian Redban (Part 1) Expecting value: line 1 column 1 (char 0)
#  98%|█████████▊| 1416/1438 [14:31<00:18,  1.18it/s]Brian Redban No results for Brian Redban
# Ari Shaffir  Expecting value: line 1 column 1 (char 0)
#  99%|█████████▊| 1417/1438 [14:33<00:24,  1.18s/it] John Heffron (Part 2) No results for John Heffron (Part 2)
#  99%|█████████▊| 1418/1438 [14:35<00:27,  1.39s/it] John Heffron (Part 1) Expecting value: line 1 column 1 (char 0)
#  99%|█████████▊| 1420/1438 [14:36<00:20,  1.12s/it]Brian Redban No results for Brian Redban
#  99%|█████████▉| 1421/1438 [14:37<00:17,  1.04s/it]Brian Redban Expecting value: line 1 column 1 (char 0)
#  99%|█████████▉| 1423/1438 [14:38<00:12,  1.15it/s]Shane Smith Multiple person results for Shane Smith
#  99%|█████████▉| 1424/1438 [14:39<00:12,  1.14it/s]Bert Kreischer (Part 2) Expecting value: line 1 column 1 (char 0)
#  99%|█████████▉| 1426/1438 [14:40<00:09,  1.32it/s]Cara Santamaria No results for Cara Santamaria
#  99%|█████████▉| 1429/1438 [14:41<00:05,  1.61it/s] Christina Pazsitzky Expecting value: line 1 column 1 (char 0)
# 100%|█████████▉| 1432/1438 [14:42<00:03,  1.91it/s]Honey Honey Multiple person results for Honey Honey
# 100%|█████████▉| 1436/1438 [14:42<00:00,  2.30it/s]Steve Volk Expecting value: line 1 column 1 (char 0)
# Steve Rinella No results for Steve Rinella
# 100%|██████████| 1438/1438 [14:45<00:00,  1.62it/s]

# %%
import json
with open("../data/jre/guests.json", "w") as f:
    f.write(json.dumps(guest_data))

# %%
# len(set([n for e, n in names]))
# len(errors), len(guest_data)
errors[:100]

# get_info(str('Duncan Trussell'))
# Out:
# [('Douglas Murray', Exception('Multiple person results for Douglas Murray')),
#  ('Edward Snowden', Exception('Multiple person results for Edward Snowden')),
#  ('Tim Kennedy', Exception('Multiple person results for Tim Kennedy')),
#  ('Ron White', Exception('Multiple person results for Ron White')),
#  ('Adam Curry', Exception('Multiple person results for Adam Curry')),
#  ('Mike Tyson', Exception('Multiple person results for Mike Tyson')),
#  ('Ali Macofsky', Exception('No results for Ali Macofsky')),
#  ('Tim Dillon', Exception('Multiple person results for Tim Dillon')),
#  (' Brian Redban', Exception('No results for Brian Redban')),
#  ('Rob Lowe', Exception('Multiple person results for Rob Lowe')),
#  ('Josh Dubin ', Exception('No results for Josh Dubin')),
#  ('Dr. Debra Soh', Exception('No results for Dr. Debra Soh')),
#  ('Mike Baker', Exception('Multiple person results for Mike Baker')),
#  ('Nancy Panza', Exception('No results for Nancy Panza')),
#  ('Post Malone', Exception('Multiple person results for Post Malone')),
#  ('Dr. Bradley Garrett', Exception('No results for Dr. Bradley Garrett')),
#  ('Andrew Huberman', Exception('No results for Andrew Huberman')),
#  ('Ben Shapiro', Exception('Multiple person results for Ben Shapiro')),
#  ('George Knapp ', Exception('Multiple person results for George Knapp')),
#  (' Jeremy Corbell', Exception('No results for Jeremy Corbell')),
#  ('Peter Schiff', Exception('Multiple person results for Peter Schiff')),
#  ('James Nestor', Exception('Multiple person results for James Nestor')),
#  ('Alan Levinovitz', Exception('No results for Alan Levinovitz')),
#  ('James Lindsay', Exception('Multiple person results for James Lindsay')),
#  ('Aron Snyder', Exception('No results for Aron Snyder')),
#  ('Jon Stewart', Exception('Multiple person results for Jon Stewart')),
#  ('Jimmy O Yang', Exception('No results for Jimmy O Yang')),
#  ('Ronnie Coleman', Exception('Multiple person results for Ronnie Coleman')),
#  ('Janet Zuccarini ', Exception('No results for Janet Zuccarini')),
#  (' Evan Funke', Exception('No results for Evan Funke')),
#  ('Honey Honey', Exception('Multiple person results for Honey Honey')),
#  ('Krystal ', Exception('Multiple person results for Krystal')),
#  (' Saagar', Exception('Multiple person results for Saagar')),
#  ('Jesus Trejo', Exception('No results for Jesus Trejo')),
#  ('Jordan Jonas', Exception('No results for Jordan Jonas')),
#  ('Adam Eget', Exception('No results for Adam Eget')),
#  ('Kevin Hart', Exception('Multiple person results for Kevin Hart')),
#  ('Tony Hawk', Exception('Multiple person results for Tony Hawk')),
#  ('Dr. Rhonda Patrick', Exception('No results for Dr. Rhonda Patrick')),
#  ('Adam Perry Lang', Exception('No results for Adam Perry Lang')),
#  ('Jack Carr', Exception('Multiple person results for Jack Carr')),
#  ('Tom Green', Exception('Multiple person results for Tom Green')),
#  ('Owen Smith', Exception('Multiple person results for Owen Smith')),
#  ("Tom O'Neill", Exception("Multiple person results for Tom O'Neill")),
#  ('Tim Dillon', Exception('Multiple person results for Tim Dillon')),
#  ('Eric Weinstein', Exception('Multiple person results for Eric Weinstein')),
#  ('Dr. Peter Hotez', Exception('No results for Dr. Peter Hotez')),
#  ('Brian Redban', Exception('No results for Brian Redban')),
#  ('Andy Stumpf', Exception('No results for Andy Stumpf')),
#  ('Jonathan Ward', Exception('Multiple person results for Jonathan Ward')),
#  ("Shannon O'Loughlin", Exception("No results for Shannon O'Loughlin")),
#  ('Michael Osterholm',
#   json.decoder.JSONDecodeError('Expecting value: line 1 column 1 (char 0)')),
#  ('Stephen Dubner', Exception('No results for Stephen Dubner')),
#  ('Adam Curry',
#   json.decoder.JSONDecodeError('Expecting value: line 1 column 1 (char 0)')),
#  (' Gary Clark Jr.',
#   json.decoder.JSONDecodeError('Expecting value: line 1 column 1 (char 0)')),
#  ('Trevor Thompson', Exception('Multiple person results for Trevor Thompson')),
#  ('Owen Smith', Exception('Multiple person results for Owen Smith')),
#  ('Raghunath Cappo',
#   json.decoder.JSONDecodeError('Expecting value: line 1 column 1 (char 0)')),
#  ('Brian Greene', Exception('Multiple person results for Brian Greene')),
#  ('Justin Martindale', Exception('No results for Justin Martindale')),
#  ('Andrew Doyle',
#   json.decoder.JSONDecodeError('Expecting value: line 1 column 1 (char 0)')),
#  ('Jim Norton', Exception('Multiple person results for Jim Norton')),
#  ('Daryl Davis', Exception('Multiple person results for Daryl Davis')),
#  ('Kevin Ross', Exception('Multiple person results for Kevin Ross')),
#  ('Rob Kearney', Exception('Multiple person results for Rob Kearney')),
#  ('Mike Baker',
#   json.decoder.JSONDecodeError('Expecting value: line 1 column 1 (char 0)')),
#  ('Bill Maher', Exception('Multiple person results for Bill Maher')),
#  ('Robert Downey Jr.', Exception('No results for Robert Downey Jr.')),
#  ('Ed Calderon',
#   json.decoder.JSONDecodeError('Expecting value: line 1 column 1 (char 0)')),
#  ('Brian Redban', Exception('No results for Brian Redban')),
#  ('Sober October 3 Recap', Exception('No results for Sober October 3 Recap')),
#  ('S.C. Gwynne',
#   json.decoder.JSONDecodeError('Expecting value: line 1 column 1 (char 0)')),
#  ('Glenn Villeneuve',
#   json.decoder.JSONDecodeError('Expecting value: line 1 column 1 (char 0)')),
#  ('Matt Farah', Exception('No results for Matt Farah')),
#  ('James Wilks ',
#   json.decoder.JSONDecodeError('Expecting value: line 1 column 1 (char 0)')),
#  (' Chris Kresser - The Game Changers Debate',
#   Exception('No results for Chris Kresser - The Game Changers Debate')),
#  ('Tim Dillon', Exception('Multiple person results for Tim Dillon')),
#  ('Chris Kresser Debunks "The Gamechangers" Documentary',
#   json.decoder.JSONDecodeError('Expecting value: line 1 column 1 (char 0)')),
#  ('Josh Homme',
#   json.decoder.JSONDecodeError('Expecting value: line 1 column 1 (char 0)')),
#  ('Paul Stamets', Exception('Multiple person results for Paul Stamets')),
#  ('RZA ', Exception('Multiple person results for RZA')),
#  ('Ben Westhoff', Exception('No results for Ben Westhoff')),
#  ('Rick Baker',
#   json.decoder.JSONDecodeError('Expecting value: line 1 column 1 (char 0)')),
#  ('Edward Norton', Exception('Multiple person results for Edward Norton')),
#  ('Kevin Smith', Exception('Multiple person results for Kevin Smith')),
#  ('Christopher Ryan',
#   Exception('Multiple person results for Christopher Ryan')),
#  ('Edward Snowden', Exception('Multiple person results for Edward Snowden')),
#  ('Richard Dawkins', Exception('Multiple person results for Richard Dawkins')),
#  ('Cameron Hanes', Exception('No results for Cameron Hanes')),
#  ('Brian Redban', Exception('No results for Brian Redban')),
#  ('Cmdr. David Fravor ', Exception('No results for Cmdr. David Fravor')),
#  (' Jeremy Corbell',
#   json.decoder.JSONDecodeError('Expecting value: line 1 column 1 (char 0)')),
#  ('Sober October 3', Exception('No results for Sober October 3')),
#  ('Sturgill Simpson ',
#   json.decoder.JSONDecodeError('Expecting value: line 1 column 1 (char 0)')),
#  (' His Band', Exception('No results for His Band')),
#  ('Sean Carroll', Exception('Multiple person results for Sean Carroll')),
#  ('David Sinclair',
#   json.decoder.JSONDecodeError('Expecting value: line 1 column 1 (char 0)')),
#  ('Zuby', Exception('Multiple person results for Zuby')),
#  ('Joseph LeDoux',
#   json.decoder.JSONDecodeError('Expecting value: line 1 column 1 (char 0)')),
#  ('John Carmack', Exception('Multiple person results for John Carmack'))]

# %%
x = {}
x.get('value', {'test':[]})['test']
x['a'] = set(['ets', 'st'])
x
# di = {'value':[]}
# Out:
# {'a': {'ets', 'st'}}
